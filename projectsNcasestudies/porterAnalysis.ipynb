# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('porter clean data.csv')
df.describe().T
# Out:
#                              count         mean          std  min     25%  \
# market_id                 183480.0     2.988462     1.530400  1.0     2.0
# order_protocol            183480.0     2.874362     1.518744 -1.0     1.0
# total_items               183480.0     2.941302     1.769003  1.0     2.0
# subtotal                  183480.0  2471.101711  1444.431123  0.0  1386.0
# num_distinct_items        183480.0     2.540310     1.372238  1.0     1.0
# min_item_price            183480.0   660.795645   429.899504  0.0   300.0
# max_item_price            183480.0  1105.304131   435.168992  0.0   799.0
# total_onshift_partners    183480.0    42.843242    31.689005  0.0    18.0
# total_busy_partners       183480.0    39.902333    29.579557  0.0    16.0
# total_outstanding_orders  183480.0    50.907750    49.673697  0.0    12.0
# Days_for_delivery         183480.0     0.000000     0.000000  0.0     0.0
# week_number               183480.0     5.903357     1.213600  4.0     5.0
#
# ...

# %%
df.describe(include='object').T
# Out:
#                          count  unique  \
# created_at              183480  169704
# actual_delivery_time    183480  167151
# store_id                183480    6671
# store_primary_category  183480      74
# primary_key_col         183480   14532
# delivery_time           183480    6994
# Time_Formatted          183480    6994
#
#                                                             top   freq
# created_at                                  2015-01-24 01:56:33      6
# actual_delivery_time                        2015-02-11 20:40:45      5
# store_id                       d43ab110ab2489d6b9b2caa394bf920f    880
# store_primary_category                                 american  18061
# primary_key_col         d43ab110ab2489d6b9b2caa394bf920fmexican    834
# delivery_time                                   0 days 00:41:23    123
# Time_Formatted                                         00:41:23    123

# %% [markdown]
# Observations:<br>
# Most of the restaurants (9% overall) have 'american' dishes as speciality<br>
# Of all orders most have an average of 3 items delivered per order<br>

# %%
plt.Figure(figsize=(12,8))
corr_matrix = df[['market_id','total_items','subtotal','num_distinct_items','min_item_price','max_item_price','Days_for_delivery','week_number']].corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
